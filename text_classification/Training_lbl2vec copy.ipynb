# %% [markdown]
# # Training the Lbl2vec model

# %% [markdown]
# ## Imports

# %%
import json
import pandas as pd
from lbl2vec import Lbl2Vec
from gensim.utils import simple_preprocess
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.parsing.preprocessing import strip_tags

# %% [markdown]
# ## Creating Lbl2vec Data
# Columns: Title, Description

# %% [markdown]
# ### Get Keywords

# %%
labels = pd.read_csv("keywords.csv")

# split keywords by separator and save them as array
labels['keywords'] = labels['Synonyms'].apply(lambda x: x.split(';'))
del labels['Synonyms']

# convert description keywords to lowercase
labels['keywords'] = labels['keywords'].apply(lambda description_keywords: [keyword.lower() for keyword in description_keywords])

# get number of keywords for each class
labels['number_of_keywords'] = labels['keywords'].apply(lambda row: len(row))

# COMMENT OUT LATER
# labels["keywords"][0] = ["murder"]

labels.head()
# Out:
#                                    Subjects  \
# 0                      Africa--Colonization
# 1                         Chinese Americans
# 2  Christianity and politics--United States
# 3              Constitutions--United States
# 4                              Cotton trade
#
#                                                 URIs  \
# 0  http://id.loc.gov/authorities/subjects/sh85001542
# 1  http://id.loc.gov/authorities/subjects/sh85024244
# 2  http://id.loc.gov/authorities/subjects/sh20081...
# 3  http://id.loc.gov/authorities/subjects/sh20091...
# 4  http://id.loc.gov/authorities/subjects/sh85033353
#
#                                             keywords  number_of_keywords
# 0             [colonize, colonization, liberia, the]                   4
# 1                    [chinese, asian, oriental, the]                   4
# 2  [church, religion, christian, protestant, meth...                   7
# 3  [constitution, amendment, declaration, bill, o...                   7
# 4            [cotton, gin, picking, plantation, the]                   5

# %% [markdown]
# ### Read JSON

# %%
path = "../data/JSON_outputs/example_data.json"
f = open(path)
json_object = json.load(f)
issues = json_object["issues"]

# %% [markdown]
# ### Get the Title/Text Dataframe

# %%
# Iterate through the json, get the texts and titles

texts = []
titles = []

for issue_number, issue in enumerate(issues):
    articles = issue["articles"]
    for article_number, article in enumerate(articles):
        text = article["ocr_text"]
        title = article["title"]
        texts.append(text)
        titles.append(title)

# Generate the dataframe

df = pd.DataFrame({
    "title": titles,
    "text": texts
})

# When previous step of the pipeline fails to get the title
# replace the title with the empty string

df = df.replace({
    "null": ""
})

df.head()
# Out:
#                                   title  \
# 0
# 1  FOR SALE AT THIS OFFICE,\nPAMPHLET,
# 2             ANTI-SLAVERY PUBLICATIONS
# 3                        SINGING SCHOOL
# 4
#
#                                                 text
# 0  ulace. The only effectual way to refute false\...
# 1  FOR SALE AT THIS OFFICE,\nPAMPHLET, entitled '...
# 2  ANTI-SLAVERY PUBLICATIONS.\nTHERE SOCIETY have...
# 3  SINGING SCHOOL.\nTHE subscriber would most res...
# 4  th\nto\nca\nm\nW\nve\n02\nW\nW\nso\na\n0\n74\n...

# %%
# df["text"][0]

# %% [markdown]
# ### Tokenize Data

# %%
# doc: document text string
# returns tokenized document
# strip_tags removes meta tags from the text
# simple preprocess converts a document into a list of lowercase tokens, ignoring tokens that are too short or too long 
# simple preprocess also removes numerical values as well as punktuation characters
def tokenize(doc):
    return simple_preprocess(strip_tags(doc), deacc=True, min_len=2, max_len=15)

# %%
# tokenize and tag documents combined title + description for Lbl2Vec training
df['tagged_docs'] = df.apply(lambda row: TaggedDocument(tokenize(row['title'] + '. ' + row['text']), [str(row.name)]), axis=1)

# %% [markdown]
# ## Train and Save the Model

# %% [markdown]
# ### Load Pre-trained Doc2vec

# %%
doc2vec_fpath = "enwiki_dbow/doc2vec.bin"
doc2vec_model = Doc2Vec.load(doc2vec_fpath)

doc2vec_model.wv.index_to_key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/danieldelijani/Desktop/CS_549/ml-bpl-liberator/lbl2vec/Training_lbl2vec copy.ipynb Cell 17' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/danieldelijani/Desktop/CS_549/ml-bpl-liberator/lbl2vec/Training_lbl2vec%20copy.ipynb#ch0000029?line=0'>1</a> doc2vec_fpath = "enwiki_dbow/doc2vec.bin"
# ----> <a href='vscode-notebook-cell:/Users/danieldelijani/Desktop/CS_549/ml-bpl-liberator/lbl2vec/Training_lbl2vec%20copy.ipynb#ch0000029?line=1'>2</a> doc2vec_model = Doc2Vec.load(doc2vec_fpath)
#       <a href='vscode-notebook-cell:/Users/danieldelijani/Desktop/CS_549/ml-bpl-liberator/lbl2vec/Training_lbl2vec%20copy.ipynb#ch0000029?line=3'>4</a> doc2vec_model.wv.index_to_key
#
# File ~/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py:813, in Doc2Vec.load(cls, *args, **kwargs)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=807'>808</a> except AttributeError as ae:
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=808'>809</a>     logger.error(
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=809'>810</a>         "Model load error. Was model saved using code from an older Gensim version? "
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=810'>811</a>         "Try loading older model using gensim-3.8.3, then re-saving, to restore "
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=811'>812</a>         "compatibility with current code.")
# --> <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=812'>813</a>     raise ae
#
# File ~/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py:807, in Doc2Vec.load(cls, *args, **kwargs)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=783'>784</a> """Load a previously saved :class:`~gensim.models.doc2vec.Doc2Vec` model.
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=784'>785</a>
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=785'>786</a> Parameters
#    (...)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=803'>804</a>
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=804'>805</a> """
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=805'>806</a> try:
# --> <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=806'>807</a>     return super(Doc2Vec, cls).load(*args, rethrow=True, **kwargs)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=807'>808</a> except AttributeError as ae:
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=808'>809</a>     logger.error(
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=809'>810</a>         "Model load error. Was model saved using code from an older Gensim version? "
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=810'>811</a>         "Try loading older model using gensim-3.8.3, then re-saving, to restore "
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py?line=811'>812</a>         "compatibility with current code.")
#
# File ~/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py:1937, in Word2Vec.load(cls, rethrow, *args, **kwargs)
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1934'>1935</a> except AttributeError as ae:
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1935'>1936</a>     if rethrow:
# -> <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1936'>1937</a>         raise ae
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1937'>1938</a>     logger.error(
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1938'>1939</a>         "Model load error. Was model saved using code from an older Gensim Version? "
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1939'>1940</a>         "Try loading older model using gensim-3.8.3, then re-saving, to restore "
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1940'>1941</a>         "compatibility with current code.")
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1941'>1942</a>     raise ae
#
# File ~/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py:1930, in Word2Vec.load(cls, rethrow, *args, **kwargs)
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1910'>1911</a> """Load a previously saved :class:`~gensim.models.word2vec.Word2Vec` model.
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1911'>1912</a>
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1912'>1913</a> See Also
#    (...)
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1926'>1927</a>
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1927'>1928</a> """
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1928'>1929</a> try:
# -> <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1929'>1930</a>     model = super(Word2Vec, cls).load(*args, **kwargs)
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1930'>1931</a>     if not isinstance(model, Word2Vec):
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/word2vec.py?line=1931'>1932</a>         rethrow = True
#
# File ~/Library/Python/3.8/lib/python/site-packages/gensim/utils.py:485, in SaveLoad.load(cls, fname, mmap)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=480'>481</a> logger.info("loading %s object from %s", cls.__name__, fname)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=482'>483</a> compress, subname = SaveLoad._adapt_by_suffix(fname)
# --> <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=484'>485</a> obj = unpickle(fname)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=485'>486</a> obj._load_specials(fname, mmap, compress, subname)
#     <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=486'>487</a> obj.add_lifecycle_event("loaded", fname=fname)
#
# File ~/Library/Python/3.8/lib/python/site-packages/gensim/utils.py:1460, in unpickle(fname)
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=1445'>1446</a> """Load object from `fname`, using smart_open so that `fname` can be on S3, HDFS, compressed etc.
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=1446'>1447</a>
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=1447'>1448</a> Parameters
#    (...)
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=1456'>1457</a>
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=1457'>1458</a> """
#    <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=1458'>1459</a> with open(fname, 'rb') as f:
# -> <a href='file:///Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/utils.py?line=1459'>1460</a>     return _pickle.load(f, encoding='latin1')
#
# AttributeError: Can't get attribute 'DocvecsArray' on <module 'gensim.models.doc2vec' from '/Users/danieldelijani/Library/Python/3.8/lib/python/site-packages/gensim/models/doc2vec.py'>

# %% [markdown]
# ### Train Model

# %%
# init model with parameters
lbl2vec_model = Lbl2Vec(keywords_list=list(labels['keywords']), doc2vec_model=doc2vec_model, label_names=list(labels['Subjects']))

# %% [markdown]
# ['colonize', 'colonization', ' liberia', 'the']
# ['chinese', 'asian', 'oriental', 'the']
# ['church', 'religion', 'christian', 'protestant', 'methodist', 'preach', 'the']
# ['constitution', 'amendment', 'declaration', 'bill', 'of', 'rights', 'the']
# ['cotton', 'gin', 'picking', 'plantation', 'the']
# ['freedmen', 'manumission', 'christiana', 'the']
# ['runaway', 'fugitive', 'abduction', 'catcher', 'the']
# ['cherokee', 'choctaw', 'seminole', 'chickasaw', 'hopewell', 'removal', 'tribe', 'tribal', 'indian', 'the']
# ['miscegenation', 'interracial', 'race-mixing', 'amalgamation', 'the']
# ['abduction', 'fugitive', 'kidnap', 'catcher', 'snatch', 'the']
# ['hanging', 'lynch', 'mob', 'vigilante', 'the']
# ['nonviolence', 'pacifism', 'pacifists', 'the']
# ['quadroon', 'quarteron', 'octoroon', 'hexadecaroon', 'biracial', 'mulatto', 'the']
# ['rebellion', 'uprising', 'haiti', 'revolt', 'boukman', 'louverture', 'nat', 'turner', 'the']
# ['poll', 'ballot', 'vote', 'voting', 'literacy', 'test', 'election', 'the']

# %%
lbl2vec_model.fit()
# Out:
# 2022-04-28 17:15:42,793 - Lbl2Vec - INFO - Train document and word embeddings
# DOC2VEC ARGS: {'documents': 0     ([ulace, the, only, effectual, way, to, refute...
# 1     ([for, sale, at, this, office, pamphlet, for, ...
# 2     ([anti, slavery, publications, anti, slavery, ...
# 3     ([singing, school, singing, school, the, subsc...
# 4     ([th, to, ca, ve, so, ste, dreadful, consequen...
# 5     ([boston, august, th, mr, wm, garrison, dear, ...
# 6     ([webster, thus, defines, blasphemy, blas, phe...
# 7     ([for, the, liberator, baptist, association, t...
# 8     ([mr, birney, letter, the, editor, of, the, ly...
# 9     ([attempted, murder, and, suicide, colored, ma...
# 10    ([list, of, letters, list, of, letters, receiv...
# 11    ([church, action, on, slavery, church, action,...
# 12    ([the, question, of, abolition, is, warmly, ag...
# 13    ([from, the, new, world, the, episcopal, spiri...
# 14    ([from, the, new, world, the, jury, law, some,...
# 15    ([the, letter, of, dr, dionysius, lardner, bru...
# 16    ([anti, slavery, in, indiana, angola, steuben,...
# 17    ([friendly, admonition, delaware, county, pa, ...
# 18    ([lingness, to, make, lithe, of, the, pecuniar...
# 19    ([convention, at, south, danvers, the, friends...
# 20    ([we, find, the, following, in, the, washingto...
# 21    ([eccentricity, finds, eccentric, reasons, for...
# 22    ([the, british, colonies, from, documents, lai...
# 23    ([items, items, it, is, stated, in, the, phila...
# 24    ([sacred, melody, sacred, melody, be, thou, go...
# 25    ([from, the, western, star, the, drunkard, unr...
# 26    ([died, died, in, goshen, conn, chloe, easton,...
# 27    ([for, the, liberator, the, last, leaf, seared...
# 28    ([from, the, amaranth, burning, letters, by, m...
# 29    ([from, the, genius, of, universal, emancipati...
# 30    ([winter, winter, by, bernard, barton, thou, h...
# 31    ([from, the, newburyport, herald, trial, of, t...
# 32    ([brazil, brazil, an, intelligent, ship, maste...
# 33    ([southern, sentiments, southern, sentiments, ...
# Name: tagged_docs, dtype: object, 'epochs': 10, 'vector_size': 300, 'min_count': 0, 'window': 15, 'sample': 1e-05, 'negative': 5, 'workers': 4, 'hs': 1, 'dm': 0, 'dbow_words': 1}
# 2022-04-28 17:15:46,853 - Lbl2Vec - INFO - Train label embeddings
# 2022-04-28 17:15:46,857 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: colonize liberia
# 2022-04-28 17:15:46,863 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: chinese asian oriental
# 2022-04-28 17:15:46,865 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: protestant methodist
# 2022-04-28 17:15:46,871 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: amendment
# 2022-04-28 17:15:46,874 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: cotton gin picking
# 2022-04-28 17:15:46,877 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: freedmen manumission christiana
# 2022-04-28 17:15:46,879 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: abduction catcher
# 2022-04-28 17:15:46,886 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: cherokee choctaw seminole chickasaw hopewell tribal indian
# 2022-04-28 17:15:46,898 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: miscegenation interracial race-mixing
# 2022-04-28 17:15:46,912 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: abduction kidnap catcher snatch
# 2022-04-28 17:15:46,915 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: lynch vigilante
# 2022-04-28 17:15:46,925 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: nonviolence pacifism pacifists
# 2022-04-28 17:15:46,929 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: quadroon quarteron octoroon hexadecaroon biracial
# 2022-04-28 17:15:46,938 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: uprising haiti revolt boukman louverture turner
# 2022-04-28 17:15:46,943 - Lbl2Vec - WARNING - The following keywords from the 'keywords_list' are unknown to the Doc2Vec model and therefore not used to train the model: poll literacy
# asking for words: ['colonize', 'colonization', 'liberia', 'the']
# using words: {'colonization', 'the'}
# asking for words: ['chinese', 'asian', 'oriental', 'the']
# using words: {'the'}
# asking for words: ['church', 'religion', 'christian', 'protestant', 'methodist', 'preach', 'the']
# using words: {'church', 'preach', 'the', 'christian', 'religion'}
# asking for words: ['constitution', 'amendment', 'declaration', 'bill', 'of', 'rights', 'the']
# using words: {'constitution', 'bill', 'declaration', 'of', 'the', 'rights'}
# asking for words: ['cotton', 'gin', 'picking', 'plantation', 'the']
# using words: {'the', 'plantation'}
# asking for words: ['freedmen', 'manumission', 'christiana', 'the']
# using words: {'the'}
# asking for words: ['runaway', 'fugitive', 'abduction', 'catcher', 'the']
# using words: {'the', 'fugitive', 'runaway'}
# asking for words: ['cherokee', 'choctaw', 'seminole', 'chickasaw', 'hopewell', 'removal', 'tribe', 'tribal', 'indian', 'the']
# using words: {'removal', 'the', 'tribe'}
# asking for words: ['miscegenation', 'interracial', 'race-mixing', 'amalgamation', 'the']
# using words: {'the', 'amalgamation'}
# asking for words: ['abduction', 'fugitive', 'kidnap', 'catcher', 'snatch', 'the']
# using words: {'the', 'fugitive'}
# asking for words: ['hanging', 'lynch', 'mob', 'vigilante', 'the']
# using words: {'the', 'hanging', 'mob'}
# asking for words: ['nonviolence', 'pacifism', 'pacifists', 'the']
# using words: {'the'}
# asking for words: ['quadroon', 'quarteron', 'octoroon', 'hexadecaroon', 'biracial', 'mulatto', 'the']
# using words: {'the', 'mulatto'}
# asking for words: ['rebellion', 'uprising', 'haiti', 'revolt', 'boukman', 'louverture', 'nat', 'turner', 'the']
# using words: {'rebellion', 'the', 'nat'}
# asking for words: ['poll', 'ballot', 'vote', 'voting', 'literacy', 'test', 'election', 'the']
# using words: {'vote', 'election', 'test', 'ballot', 'the', 'voting'}

# %%
# lbl2vec_model.save(".")

# %% [markdown]
# ## Make predictions

# %%
model_docs_lbl_similarities = lbl2vec_model.predict_model_docs()

model_docs_lbl_similarities
# Out:
# 2022-04-28 17:16:26,817 - Lbl2Vec - INFO - Get document embeddings from model
# 2022-04-28 17:16:26,821 - Lbl2Vec - INFO - Calculate document<->label similarities

# %%
new_docs_lbl_similarities = lbl2vec_model.predict_new_docs(tagged_docs=df['tagged_docs'])
new_docs_lbl_similarities
# Out:
#    doc_key                        most_similar_label  \
# 0        0                  Indians of North America
# 1        1                                Kidnapping
# 2        2                           Fugitive slaves
# 3        3                  Indians of North America
# 4        4  Christianity and politics--United States
# 5        5  Christianity and politics--United States
# 6        6                       Slave insurrections
# 7        7                     Racially mixed people
# 8        8                  Indians of North America
# 9        9              Constitutions--United States
# 10      10                              Cotton trade
# 11      11                           Fugitive slaves
# 12      12  Christianity and politics--United States
# 13      13                       Slave insurrections
# 14      14                       Slave insurrections
# 15      15                  Indians of North America
# 16      16  Christianity and politics--United States
# 17      17                                Kidnapping
# 18      18                           Fugitive slaves
# 19      19                       Slave insurrections
# 20      20  Christianity and politics--United States
# 21      21              Constitutions--United States
# 22      22                      Interracial marriage
# 23      23                         Chinese Americans
# 24      24                                  Lynching
# 25      25                      Africa--Colonization
# 26      26                              Cotton trade
# 27      27  Christianity and politics--United States
# 28      28                  Indians of North America
# 29      29                                Kidnapping
# 30      30              Constitutions--United States
# 31      31                  Indians of North America
# 32      32              Constitutions--United States
# 33      33                         Chinese Americans
#
#     highest_similarity_score  Africa--Colonization  Chinese Americans  \
# 0                   0.843478              0.843478           0.843478
# 1                   0.930938              0.930938           0.930938
# 2                   0.892044              0.892044           0.892044
# 3                   0.688551              0.688551           0.688551
# 4                   0.523468              0.523468           0.523468
# 5                   0.735022              0.735022           0.735022
# 6                   0.875167              0.875167           0.875167
# 7                   0.701596              0.701596           0.701596
# 8                   0.738099              0.738099           0.738099
# 9                   0.648984              0.648984           0.648984
# 10                  0.822953              0.822953           0.822953
# 11                  0.726383              0.726383           0.726383
# 12                  0.771398              0.771398           0.771398
# 13                  0.463609              0.463609           0.463609
# 14                  0.861482              0.861482           0.861482
# 15                  0.603888              0.603888           0.603888
# 16                  0.545218              0.545218           0.545218
# 17                  0.595129              0.595129           0.595129
# 18                  0.746878              0.746878           0.746878
# 19                  0.788966              0.788966           0.788966
# 20                  0.857434              0.857434           0.857434
# 21                  0.761134              0.761134           0.761134
